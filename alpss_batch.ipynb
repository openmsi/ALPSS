# %%
from alpss_main import alpss_main
import json

# %%
files =

# %%
for file in files:
    print("Processing file...")
    config = json.load('ALPSS/tests/input_data')
    config['filepath'] = 
    fig, items = alpss_main(**config)
